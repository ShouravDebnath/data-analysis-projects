# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("UberDataset.csv")

# %%
df
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
df.shape
# Out:
# (1156, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1156 non-null   object
#  1   END_DATE    1155 non-null   object
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1156 non-null   float64
#  6   PURPOSE     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %% [markdown]
# # Data preprocessing

# %%
df["PURPOSE"].fillna("NOT", inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13356\3694066947.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["PURPOSE"].fillna("NOT", inplace=True)

# %%
df.head()
# Out:
#          START_DATE          END_DATE  CATEGORY        START             STOP  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES          PURPOSE
# 0    5.1   Meal/Entertain
# 1    5.0              NOT
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %%
df["START_DATE"] = pd.to_datetime(df["START_DATE"], errors = "coerce")

df["END_DATE"] = pd.to_datetime(df["END_DATE"], errors = "coerce")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  421 non-null    datetime64[ns]
#  1   END_DATE    420 non-null    datetime64[ns]
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1156 non-null   float64
#  6   PURPOSE     1156 non-null   object
# dtypes: datetime64[ns](2), float64(1), object(4)
# memory usage: 63.3+ KB

# %%
from datetime import datetime

df["data"] = pd.DatetimeIndex(df["START_DATE"]).date
df["time"] = pd.DatetimeIndex(df["START_DATE"]).hour

# %%
df.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        data  time
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0

# %%
df["day-night"] = pd.cut(x=df["time"], bins = [0,10,15,19,24], labels = ["Morning","Afternoon","Evening","Night"])

# %%
df.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        data  time  day-night
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0      Night
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0    Morning
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0      Night
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0    Evening
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0  Afternoon

# %%
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (413, 10)

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # In which category do people book the most Uber rides and for which purpose do people book Uber rides the most?

# %%
plt.figure(figsize=(20,5))


plt.subplot(1,2,1)
sns.countplot(df["CATEGORY"])
plt.xlabel("People")
plt.title("Graph of Category")


plt.subplot(1,2,2)
sns.countplot(df["PURPOSE"], color="Maroon")
plt.xlabel("People")
plt.title("Graph of Purpose")

plt.tight_layout()

# %% [markdown]
# # At what time do people book cabs the most from Uber

# %%
sns.countplot(df["day-night"],
               edgecolor="black",
               linewidth=1,
               color="sandybrown"
)
plt.title("Day-Night Wise People Count")
plt.xlabel("people")
# Out:
# Text(0.5, 0, 'people')

# %% [markdown]
# # In which months do people book Uber rides less frequently

# %%
df["month"] = df["START_DATE"].dt.month_name()

# %%
df.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        data  time  day-night  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0      Night
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0    Morning
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0      Night
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0    Evening
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0  Afternoon
#
#      month
# 0  January
# 1  January
# 2  January
# 3  January
# 4  January

# %%
month_counts = df["month"].value_counts().sort_values()
month_counts
# Out:
# month
# September    13
# January      23
# April        24
# October      24
# May          26
# July         34
# December     39
# February     40
# March        42
# June         42
# August       43
# November     63
# Name: count, dtype: int64

# %%
sns.countplot(
    y=df["month"],
    order=df["month"].value_counts().sort_values().index,
    edgecolor="black",
    linewidth=1,
    color="powderblue"
)

plt.title("Uber Rides per Month (Less to More)")
plt.xlabel("Number of Rides")
plt.ylabel("Month")

plt.show()

# %% [markdown]
# # On which days of the week do people book Uber rides the most

# %%
df["weekday"] = df["START_DATE"].dt.day_name()

# %%
df.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        data  time  day-night  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0      Night
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0    Morning
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0      Night
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0    Evening
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0  Afternoon
#
#      month    weekday
# 0  January     Friday
# 1  January   Saturday
# 2  January   Saturday
# 3  January    Tuesday
# 4  January  Wednesday

# %%
weekday_counts = df["weekday"].value_counts()
weekday_counts
# Out:
# weekday
# Friday       86
# Thursday     61
# Monday       61
# Tuesday      58
# Saturday     52
# Wednesday    48
# Sunday       47
# Name: count, dtype: int64

# %%
sns.countplot(
    x=df["weekday"],
    order=df["weekday"].value_counts().index,
    edgecolor="black",
    linewidth=1,
    color="yellowgreen"
)

plt.title("Uber Rides by Day of Week (Most to Least)")
plt.xlabel("Number of Rides")
plt.ylabel("Day of Week")
plt.tight_layout()
plt.show()

# %%
df["MILES"].median()

# %%
sns.histplot(df["MILES"], bins=20, kde=True)

plt.title("Distribution of Uber Ride Distances")
plt.xlabel("Miles")
plt.ylabel("Number of Rides")
plt.tight_layout()
plt.show()
